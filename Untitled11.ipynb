# %% [markdown]
# <a href="https://colab.research.google.com/github/leo10-beep/activity/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Corrected: Load a standard dataset from sklearn.datasets
Students = datasets.load_iris()

x = Students.data
y = Students.target

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# Corrected: Refer to feature_names correctly
print(Students.feature_names)
print(x_train[0])
print(y_train[0])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# [4.6 3.6 1.  0.2]
# 0
